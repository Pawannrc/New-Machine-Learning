# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('salary_dataset.csv')

# %%
data.drop(columns='Unnamed: 0',inplace=True)

# %%
data.head(3)
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x='YearsExperience',y='Salary',data=data)
plt.show()

# %%
x=data['YearsExperience']
y=data['Salary']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
len(x_train)
# Out:
# 24

# %%
len(x_test)
# Out:
# 6

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree

# %%
dc=DecisionTreeRegressor(criterion= "absolute_error")   # used to improve generate better score and result
dc.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='absolute_error')

# %%
dc.score(x_test,y_test)*100, dc.score(x_train,y_train)*100
# Out:
# (97.64754205531827, 99.65651820805788)

# %%
dc.predict([[1.4]])
# Out:
# C:\Program Files\Python39\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([46206.])

# %%
plt.figure(figsize=(10,10))
plot_tree(dc)
plt.show()
