# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('salary_dataset.csv')
data.head(3)
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0

# %%
data.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x=data[['YearsExperience']]

# %%
y=data[['Salary']]

# %%
plt.figure(figsize=(5,3))
sns.lmplot(x='YearsExperience',y='Salary',data=data)

plt.show()

# %%
sns.heatmap(data=data.corr(),annot=True)
plt.figure(figsize=(3,3))

# %%
#from sklearn.preprocessing import PolynomialFeatures

# %%
#poly=PolynomialFeatures(degree=2)

# %%
#x=poly.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
len(x_train)

# %%
len(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression(poly)

# %%
lr.fit(data[['YearsExperience']],data['Salary'])

# %%
lr.predict([[1.4]])
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([38078.15121656])

# %%
lr.score(x_test,y_test)*100,lr.score(x_train,y_train)
# Out:
# (98.99356101129206, 0.9408505111069246)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
print(mean_squared_error(y_test,lr.predict(x_test)))
print(mean_absolute_error (y_test,lr.predict(x_test)))
print(np.sqrt((mean_squared_error(y_test,lr.predict(x_test)))))
# Out:
# 10909090.287102874
# 2304.2056011630943
# 3302.8912012209657

# %%
from sklearn.linear_model import Lasso

# %%
lss=Lasso(alpha=0.5)
lss.fit(x_train, y_train)
lss.score(x_test,y_test)*100
# Out:
# 98.81688216126102

# %%
from sklearn.linear_model import Ridge

# %%
ri=Ridge(alpha=0.5)
ri.fit(x_train,y_train)
ri.score(x_test,y_test)*100
# Out:
# 98.7891303817413
